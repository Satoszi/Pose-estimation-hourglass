# %%
import cv2
import numpy as np
import os
import scipy.io as io
import matplotlib.pyplot as plt
import pickle

# Tensorfloww
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras import layers

import random
from tqdm import tqdm

# %%
IMG_SIZE = 96

# %%
with open('../../../RGBD/train_test_2.pickle', 'rb') as fp:
    x_train,y_train,x_test,y_test = pickle.load(fp)

# %%
print(y_train.shape)
print(y_test.shape)
print(x_test.shape)
#plt.imshow(x_test[10])
#plt.imshow(y_test[250,:,:,8])
# Out:
# (4424, 96, 96, 15)
# (489, 96, 96, 15)
# (489, 96, 96, 3)

# %% [markdown]
# ## Generators

# %%
def my_generator(image_data_generator, mask_data_generator):
    train_generator = zip(image_data_generator,mask_data_generator)
    for (img,mask) in train_generator:
        yield (img, mask)

# %%
generator_x = tf.keras.preprocessing.image.ImageDataGenerator(
    #rotation_range=35,
    #height_shift_range=0.15,
    #width_shift_range=0.15,
    #zoom_range=0.15,
    #shear_range=30,
    #channel_shift_range = 0.4,
    #fill_mode = 'nearest',
    #validation_split=0.1
)

generator_y = tf.keras.preprocessing.image.ImageDataGenerator(
    #rotation_range=35,
    #height_shift_range=0.15,
    #width_shift_range=0.15,
    #zoom_range=0.15,
    #shear_range=35,
    #channel_shift_range = 0.4,
    #fill_mode = "constant",
    #cval = 0
    #validation_split=0.1
)

# %%
SEED = 123
image_generator = generator_x.flow(x_train,seed=SEED,batch_size=16, shuffle=True)
mask_generator = generator_y.flow(y_train,seed=SEED,batch_size=16, shuffle=True)
# Out:
# C:\Users\mati\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\preprocessing\image.py:680: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (4424, 96, 96, 15) (15 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '

# %%
image_generator_val = generator_x.flow(x_test,seed=SEED,batch_size=16, shuffle=True)
mask_generator_val = generator_y.flow(y_test,seed=SEED,batch_size=16, shuffle=True)
# Out:
# C:\Users\mati\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\preprocessing\image.py:680: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (489, 96, 96, 15) (15 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '

# %%
generator = my_generator(image_generator,mask_generator)
train_test_generator = my_generator(image_generator,mask_generator)
val_generator = my_generator(image_generator_val,mask_generator_val)

# %%
a = next(val_generator)

# %%
idx = 0
plt.imshow(a[0][idx])

# %%
sumed_masks = np.zeros((IMG_SIZE,IMG_SIZE))
for j in range(15):
    sumed_masks += a[1][idx,:,:,j]
plt.imshow(sumed_masks)

# %% [markdown]
# ## Utils

# %%
def get_blob_center(heatmap):
    
    heatmap_size = heatmap.shape[0]
    heatmap = np.abs(heatmap)
    heatmap = heatmap*heatmap*heatmap
    
    dx = np.array(np.arange(0,heatmap_size))
    dx = np.expand_dims(dx,0)
    dx = np.repeat(dx,heatmap_size, axis=0)
    dy = np.rot90(dx, k=3)
    
    heatmap_dx = dx*heatmap
    heatmap_dy = dy*heatmap
    
    sumed_heatmap = np.sum(heatmap)
    x = np.sum(heatmap_dx)/sumed_heatmap
    y = np.sum(heatmap_dy)/sumed_heatmap
    return np.array([x, y])

def isNaN(num):
    return num != num

def calc_blob_distances(mask_gt, mask_pred):
    distances = []
    for i in range(mask_gt.shape[-1]):
        heatmap_gt, heatmap_pred = mask_gt[:,:,i],mask_pred[:,:,i]
        p_gt = get_blob_center(heatmap_gt)
        p_pred = get_blob_center(heatmap_pred)
        distance = np.linalg.norm(p_gt-p_pred)
        if isNaN(distance):
            distance = None
        distances.append(distance)
    cleaned_distances = [x for x in distances if x != None]
    return cleaned_distances
        
def calc_oks_metric(model_to_eval, val_generator, probes):
    
    x = []
    y_gt = []
    for probe in range(probes):
        x1, y_gt1 = next(val_generator)
        x.append(x1[0])
        y_gt.append(y_gt1[0])
        if x1.shape[0] > 1:
            x.append(x1[1])
            x.append(x1[2])
            x.append(x1[3])
            x.append(x1[4])
            x.append(x1[5])
            x.append(x1[6])
            x.append(x1[7])
            y_gt.append(y_gt1[1])
            y_gt.append(y_gt1[2])
            y_gt.append(y_gt1[3])
            y_gt.append(y_gt1[4])
            y_gt.append(y_gt1[5])
            y_gt.append(y_gt1[6])
            y_gt.append(y_gt1[7])
    all_frames_distances = []
    y_pred = model_to_eval.predict(np.array(x),verbose = 0)
    x = np.array(x)
    y_gt = np.array(y_gt)
    y_pred = np.array(y_pred)
    for probe in range(probes):
        per_frame_distances = calc_blob_distances(y_gt[probe],y_pred[probe])
        per_frame_distances_avg = np.average(per_frame_distances)
        #print(per_frame_distances_avg)
        all_frames_distances.append(per_frame_distances_avg)
    average_dist = np.average(all_frames_distances)
    return average_dist

# %%
history_oks = []

# %%
class my_callback(tf.keras.callbacks.Callback):
    def on_batch_end(self, batch, logs=None):
        if batch % 500 == 0:
            print()
            print("Evaulating...")
            train_oks = calc_oks_metric(model_2, train_test_generator, 40)
            val_oks = calc_oks_metric(model_2, val_generator, 40)
            history_oks.append((train_oks,val_oks))
            print("train_oks:",train_oks,"val_oks:",val_oks)
            return None

# %% [markdown]
# ## Model

# %%
w_init = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

# %%
def unet_conv(inputs, filters, kernel_size=3, padding="same", strides=2, activation=True):
    x = Conv2D(
        filters=filters,
        kernel_size=kernel_size,
        kernel_initializer=w_init,
        padding=padding,
        strides=strides,
    )(inputs)
    if activation:
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Dropout(0.1)(x)
    return x

# %%
def unet_up_conv(inputs, filters, kernel_size=3, padding="same", strides=2, activation=True):
    x = Conv2DTranspose(
        filters=filters,
        kernel_size=kernel_size,
        kernel_initializer=w_init,
        padding=padding,
        strides=strides,
        use_bias=True
    )(inputs)
    if activation:
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Dropout(0.1)(x)
    return x

# %%
def build_generator(img_size=32, num_channels=3):
    
    inputs = keras.Input(shape=(img_size,img_size,num_channels,))
    x1 = unet_conv(inputs, filters = 32, strides = 1)
    
    x2 = unet_conv(x1, filters = 32, strides = 2)
    x3 = unet_conv(x2, filters = 32, strides = 1)
    
    x4 = unet_conv(x3, filters = 64, strides = 2)
    x5 = unet_conv(x4, filters = 64, strides = 1)
    
    x6 = unet_conv(x5, filters = 128, strides = 2)
    x7 = unet_conv(x6, filters = 128, strides = 1)
    
    
    x8 = unet_conv(x7, filters = 256, strides = 2)
    x9 = unet_conv(x8, filters = 256, strides = 1)
    
    x10 = unet_up_conv(x9, filters = 256, strides = 2)
    
    
    x = layers.concatenate([x7, x10])
    x11 = unet_conv(x, filters = 256, strides = 1)
    x12 = unet_up_conv(x11, filters = 256, strides = 2)
    
    x = layers.concatenate([x5, x12])
    x13 = unet_conv(x, filters = 128, strides = 1)
    x14 = unet_up_conv(x13, filters = 128, strides = 2)
    
    x = layers.concatenate([x3, x14])
    x15 = unet_conv(x, filters = 64, strides = 1)
    x16 = unet_up_conv(x15, filters = 64, strides = 2)
    
    x = layers.concatenate([x1, x16, inputs])
    x17 = unet_conv(x, filters = 64, strides = 1)
    
    x = layers.Conv2D(15, kernel_size = 3, padding="same")(x17)
    output = Activation("sigmoid", name="head1")(x)

    # Define the model
    model = keras.Model(inputs, outputs = [output])
    
    return model

# %%
model_2 = build_generator(IMG_SIZE)

# %%
#model_2.summary()

# %% [markdown]
# ## Training

# %%
# global custom_history
# custom_history = []

# %%
# class CustomCallback(keras.callbacks.Callback):
#     def on_train_batch_end(self, batch, logs=None):
#         global custom_history
#         if (batch % 100000 == 99999):
#             keys = list(logs.keys())
#             #print("TROLO", logs["head1_loss"], logs["head2_loss"])
#             train_loss = model_2.evaluate(x_train[::10],y_train[::10])
#             test_loss = model_2.evaluate(x_test[::10],y_test[::10])
#             custom_history.append((train_loss,test_loss, [logs["loss"], logs["head1_loss"], logs["head2_loss"]]))
#             print(custom_history[-1])

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model_2.compile(optimizer=opt, loss = "mse")

# %%
val_oks = calc_oks_metric(model_2, val_generator, 10)
print(val_oks)
#print(history_oks)
# Out:
# 22.301509995897444
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\1404756432.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   x = np.sum(heatmap_dx)/sumed_heatmap
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\1404756432.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   y = np.sum(heatmap_dy)/sumed_heatmap

# %%
val_oks = calc_oks_metric(model_2, train_test_generator, 10)
print(val_oks)
# Out:
# 23.620125861174635
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\1404756432.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   x = np.sum(heatmap_dx)/sumed_heatmap
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\1404756432.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   y = np.sum(heatmap_dy)/sumed_heatmap

# %%
model_2.fit(generator, epochs = 50, batch_size = 16, 
            callbacks=[my_callback()]
           )
# Out:
# Epoch 1/50
#
# Evaulating...
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\3474546752.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   x = np.sum(heatmap_dx)/sumed_heatmap
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\3474546752.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   y = np.sum(heatmap_dy)/sumed_heatmap
# train_oks: 11.381383179492149 val_oks: 15.813466301674277
#       6/Unknown - 5s 136ms/step - loss: 0.0222 - head1_loss: 0.0116 - head2_loss: 0.0106WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0935s vs `on_train_batch_end` time: 0.7906s). Check your callbacks.
#     500/Unknown - 72s 135ms/step - loss: 0.0213 - head1_loss: 0.0112 - head2_loss: 0.0101
# Evaulating...
# train_oks: 8.882775149528111 val_oks: 13.608236658828588
#    1000/Unknown - 144s 140ms/step - loss: 0.0204 - head1_loss: 0.0107 - head2_loss: 0.0096
# Evaulating...
# train_oks: 7.938895960291151 val_oks: 9.844458483138794
#    1500/Unknown - 216s 141ms/step - loss: 0.0194 - head1_loss: 0.0103 - head2_loss: 0.0091
# Evaulating...
# train_oks: 4.44015654535382 val_oks: 9.853380367386078
#    2000/Unknown - 287s 141ms/step - loss: 0.0186 - head1_loss: 0.0099 - head2_loss: 0.0086
# Evaulating...
# train_oks: 4.591842839442012 val_oks: 7.948473567346397
#    2500/Unknown - 359s 142ms/step - loss: 0.0177 - head1_loss: 0.0095 - head2_loss: 0.0082
# Evaulating...
# train_oks: 3.276289835641331 val_oks: 7.900731222163296
#    3000/Unknown - 430s 142ms/step - loss: 0.0169 - head1_loss: 0.0091 - head2_loss: 0.0078
# Evaulating...
# train_oks: 3.520756227079577 val_oks: 8.481207523944985
#    3500/Unknown - 502s 142ms/step - loss: 0.0162 - head1_loss: 0.0088 - head2_loss: 0.0074
# Evaulating...
# train_oks: 3.2516919200687626 val_oks: 8.034701624155833
#    4000/Unknown - 573s 142ms/step - loss: 0.0156 - head1_loss: 0.0084 - head2_loss: 0.0071
# Evaulating...
# train_oks: 2.867038364882054 val_oks: 7.298243618569225
#    4500/Unknown - 645s 142ms/step - loss: 0.0150 - head1_loss: 0.0081 - head2_loss: 0.0069
# Evaulating...
# train_oks: 2.5657152522652353 val_oks: 9.150705798138503
#    5000/Unknown - 717s 142ms/step - loss: 0.0145 - head1_loss: 0.0079 - head2_loss: 0.0066
# Evaulating...
# train_oks: 2.44159757985297 val_oks: 6.90052797815788
#    5500/Unknown - 788s 142ms/step - loss: 0.0140 - head1_loss: 0.0076 - head2_loss: 0.0064
# Evaulating...
# train_oks: 2.0035306842722758 val_oks: 7.660354438837137
#    6000/Unknown - 860s 143ms/step - loss: 0.0136 - head1_loss: 0.0074 - head2_loss: 0.0062
# Evaulating...
# train_oks: 1.819397160214694 val_oks: 7.596073045385557
#    6087/Unknown - 876s 143ms/step - loss: 0.0135 - head1_loss: 0.0074 - head2_loss: 0.0061
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 model_2.fit(generator, epochs = 50, batch_size = 16,
#       2             callbacks=[my_callback()]
#       3            )
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\engine\training.py:1414, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412 logs = tmp_logs  # No error, now safe to assign to logs.
#    1413 end_step = step + data_handler.step_increment
# -> 1414 callbacks.on_train_batch_end(end_step, logs)
#    1415 if self.stop_training:
#    1416   break
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:353, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     350 if self._check_timing:
#     351   start_time = time.time()
# --> 353 logs = self._process_logs(logs, is_batch_hook=True)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:272, in CallbackList._process_logs(self, logs, is_batch_hook)
#     270 if is_batch_hook and self._batch_hooks_support_tf_logs:
#     271   return logs
# --> 272 return tf_utils.sync_to_numpy_or_python_type(logs)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\utils\tf_utils.py:607, in sync_to_numpy_or_python_type(tensors)
#     604     return t
#     605   return t.item() if np.ndim(t) == 0 else t
# --> 607 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\util\nest.py:916, in map_structure(func, *structure, **kwargs)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\util\nest.py:916, in <listcomp>(.0)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\utils\tf_utils.py:601, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     598 def _to_single_numpy_or_python_type(t):
#     599   # Don't turn ragged or sparse tensors to NumPy.
#     600   if isinstance(t, tf.Tensor):
# --> 601     t = t.numpy()
#     602   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     603   if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\framework\ops.py:1159, in _EagerTensorBase.numpy(self)
#    1136 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1137
#    1138 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1156     NumPy dtype.
#    1157 """
#    1158 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1159 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1160 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\framework\ops.py:1125, in _EagerTensorBase._numpy(self)
#    1123 def _numpy(self):
#    1124   try:
# -> 1125     return self._numpy_internal()
#    1126   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1127     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
model_2.fit(generator, epochs = 50, batch_size = 16, 
            callbacks=[my_callback()]
           )
# Out:
# Epoch 1/50
#
# Evaulating...
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\1404756432.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   x = np.sum(heatmap_dx)/sumed_heatmap
# C:\Users\mati\AppData\Local\Temp\ipykernel_20084\1404756432.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   y = np.sum(heatmap_dy)/sumed_heatmap
# train_oks: 23.975031294018144 val_oks: 23.515817063461945
#       6/Unknown - 6s 81ms/step - loss: 0.2000WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0610s vs `on_train_batch_end` time: 0.5075s). Check your callbacks.
#     500/Unknown - 46s 81ms/step - loss: 0.0165
# Evaulating...
# train_oks: 18.384826735664234 val_oks: 20.342785174363748
#    1000/Unknown - 90s 84ms/step - loss: 0.0142
# Evaulating...
# train_oks: 13.784382207967104 val_oks: 16.915692134676334
#    1500/Unknown - 133s 85ms/step - loss: 0.0131
# Evaulating...
# train_oks: 11.867869705255327 val_oks: 17.83044367389107
#    2000/Unknown - 177s 86ms/step - loss: 0.0123
# Evaulating...
# train_oks: 7.157766331818211 val_oks: 12.056686252026324
#    2500/Unknown - 220s 86ms/step - loss: 0.0116
# Evaulating...
# train_oks: 8.640805611537326 val_oks: 11.444095787677849
#    3000/Unknown - 264s 86ms/step - loss: 0.0110
# Evaulating...
# train_oks: 7.611217239027162 val_oks: 10.695925653485517
#    3500/Unknown - 308s 86ms/step - loss: 0.0105
# Evaulating...
# train_oks: 7.221875820724577 val_oks: 8.405176661652098
#    4000/Unknown - 352s 87ms/step - loss: 0.0100
# Evaulating...
# train_oks: 4.074450338149207 val_oks: 10.785075704451307
#    4500/Unknown - 395s 87ms/step - loss: 0.0095
# Evaulating...
# train_oks: 3.1952475911234766 val_oks: 10.066387506526093
#    5000/Unknown - 439s 87ms/step - loss: 0.0091
# Evaulating...
# train_oks: 2.6922930901789632 val_oks: 8.138549843986315
#    5500/Unknown - 482s 87ms/step - loss: 0.0088
# Evaulating...
# train_oks: 2.4714395767151616 val_oks: 11.27088132372494
#    6000/Unknown - 526s 87ms/step - loss: 0.0085
# Evaulating...
# train_oks: 2.5860195294311725 val_oks: 9.209945285237666
#    6500/Unknown - 569s 87ms/step - loss: 0.0082
# Evaulating...
# train_oks: 2.7801655201005024 val_oks: 11.877548398469198
#    7000/Unknown - 612s 87ms/step - loss: 0.0079
# Evaulating...
# train_oks: 4.2424171284305805 val_oks: 6.724922471112437
#    7500/Unknown - 656s 87ms/step - loss: 0.0077
# Evaulating...
# train_oks: 2.125093893638298 val_oks: 10.376099707045054
#    7576/Unknown - 665s 87ms/step - loss: 0.0076
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 model_2.fit(generator, epochs = 50, batch_size = 16,
#       2             callbacks=[my_callback()]
#       3            )
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\engine\training.py:1414, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412 logs = tmp_logs  # No error, now safe to assign to logs.
#    1413 end_step = step + data_handler.step_increment
# -> 1414 callbacks.on_train_batch_end(end_step, logs)
#    1415 if self.stop_training:
#    1416   break
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:353, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     350 if self._check_timing:
#     351   start_time = time.time()
# --> 353 logs = self._process_logs(logs, is_batch_hook=True)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\callbacks.py:272, in CallbackList._process_logs(self, logs, is_batch_hook)
#     270 if is_batch_hook and self._batch_hooks_support_tf_logs:
#     271   return logs
# --> 272 return tf_utils.sync_to_numpy_or_python_type(logs)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\utils\tf_utils.py:607, in sync_to_numpy_or_python_type(tensors)
#     604     return t
#     605   return t.item() if np.ndim(t) == 0 else t
# --> 607 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\util\nest.py:916, in map_structure(func, *structure, **kwargs)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\util\nest.py:916, in <listcomp>(.0)
#     912 flat_structure = (flatten(s, expand_composites) for s in structure)
#     913 entries = zip(*flat_structure)
#     915 return pack_sequence_as(
# --> 916     structure[0], [func(*x) for x in entries],
#     917     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\keras\utils\tf_utils.py:601, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     598 def _to_single_numpy_or_python_type(t):
#     599   # Don't turn ragged or sparse tensors to NumPy.
#     600   if isinstance(t, tf.Tensor):
# --> 601     t = t.numpy()
#     602   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     603   if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\framework\ops.py:1159, in _EagerTensorBase.numpy(self)
#    1136 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1137
#    1138 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1156     NumPy dtype.
#    1157 """
#    1158 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1159 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1160 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\anaconda3\envs\tensorflow_gpu_2022_07\lib\site-packages\tensorflow\python\framework\ops.py:1125, in _EagerTensorBase._numpy(self)
#    1123 def _numpy(self):
#    1124   try:
# -> 1125     return self._numpy_internal()
#    1126   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1127     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
train_oks = [x[0] for x in history_oks]
val_oks = [x[1] for x in history_oks]
plt.plot(train_oks) 
plt.plot(val_oks)
plt.show()

# %%
model_2.save("heatmap_192_hourglass_3_modules_all_keypoints_3")

# %% [markdown]
# ## Tests

# %%
model_5 = keras.models.load_model('no_overfit')
#model_2.save("no_overfit")

# %%
inter_output_2 = model_5.predict(x_test[0:200])
inter_output_2 = np.array(inter_output_2)
# Out:
# 7/7 [==============================] - 1s 103ms/step

# %%
idx = 70
plt.imshow(inter_output_2[1,idx,:,:,0])
inter_output_2[1,idx,:,:,14].max()
# Out:
# 0.10015857

# %%
idx_2 = 13
plt.imshow(x_test[idx])

# %%
#f.set_figheight(15)
f, axarr = plt.subplots(1,3, figsize=(10, 10))

axarr[0].imshow(y_test[idx,:,:,idx_2])
axarr[1].imshow(inter_output_2[0][idx,:,:,idx_2])
axarr[2].imshow(inter_output_2[1][idx,:,:,idx_2])

# %%
model_2.evaluate(x_test,y_test, batch_size = 16)
# Out:
# 31/31 [==============================] - 3s 57ms/step - loss: 0.0176 - head1_loss: 0.0092 - head2_loss: 0.0084
# [0.017612367868423462, 0.009191948920488358, 0.008420419879257679]

# %%
addon = 400
per_once = 50

# %%
predicted = model_2.predict(x_test[addon:addon+per_once])
# Out:
# 2/2 [==============================] - 0s 48ms/step

# %%
predicted = predicted[0]

# %%
masks_video = []

for i in range(per_once):
    sumed_masks_l = np.zeros((IMG_SIZE,IMG_SIZE,3))
    sumed_masks_r = np.zeros((IMG_SIZE,IMG_SIZE,3))
    for j in range(15):
        if (j % 2 == 0):
            sumed_masks_l[:,:,0] += predicted[i,:,:,j]
        if (j % 2 == 1):
            sumed_masks_r[:,:,2] += predicted[i,:,:,j]
            
    sumed_masks_l += sumed_masks_r
    #sumed_masks_l = sumed_masks_l**2/255.
    masks_video.append(sumed_masks_l)

# %%
np.array(masks_video).shape
# Out:
# (50, 96, 96, 3)

# %%
for i in range(per_once):
    cv2.imshow("window1", cv2.resize(masks_video[i]*1,(256,256)))
    cv2.imshow("window2", cv2.resize(x_test[addon+i]/1.,(256,256)))
    cv2.waitKey(200)
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()
